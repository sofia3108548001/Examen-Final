# %% [markdown]
# <a href="https://colab.research.google.com/github/sofia3108548001/Examen-Final/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip  install pandas

# %%
import geopandas as gpd
import pandas as pd

# !pip install contextily
import contextily as cx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 58.4 MB/s eta 0:00:00
# ...

# %%
municipios = gpd.read_file("tolima.csv")
municipios
# Out:
#                                     Código Departamento Código Municipio  \
# 0                                                    05            05001
# 1                                                    05            05002
# 2                                                    05            05004
# 3                                                    05            05021
# 4                                                    05            05030
# ...                                                 ...              ...
# 1121                                      Fuente: DANE.
# 1122  Nota: En la actualidad el país se compone de 1...
# 1123                Actualizado al: 10 de Junio de 2020
# 1124  *Desde el 1 de diciembre de 2019 comenzó a reg...
# 1125  conformado por las áreas no municipalizadas de...
#
#      Nombre Departamento Nombre Municipio  \
# 0              ANTIOQUIA         MEDELLÍN
# 1              ANTIOQUIA        ABEJORRAL
# 2              ANTIOQUIA         ABRIAQUÍ
# ...

# %%
# Out:
# <Axes: >
